# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Survey_data.csv', delimiter=',', header=0)
df1.head()
# Out:
#        Id             Satisfaction Seat_comfort  \
# 0  198671  neutral or dissatisfied         poor
# 1  193378                satisfied    excellent
# 2  174522                satisfied         good
# 3  191830                satisfied         good
# 4  221497                satisfied         good
#
#   Departure.Arrival.time_convenient  Food_drink Gate_location  \
# 0                        acceptable  acceptable    manageable
# 1                  need improvement   excellent    Convinient
# 2                              good        good    manageable
# 3                              good        good    manageable
# 4                              good         NaN    Convinient
#
#   Inflightwifi_service Inflight_entertainment Online_support  \
# 0                 poor       need improvement           poor
# 1           acceptable              excellent     acceptable
# 2           acceptable              excellent      excellent
# ...

# %%
df2 = pd.read_csv('Flight+data.csv', delimiter=',', header=0)
df2.head()
# Out:
#        ID  Gender    CustomerType  Age       TypeTravel Class  \
# 0  149965  Female  Loyal Customer   65  Personal Travel   Eco
# 1  149966  Female  Loyal Customer   15  Personal Travel   Eco
# 2  149967  Female  Loyal Customer   60  Personal Travel   Eco
# 3  149968  Female  Loyal Customer   70  Personal Travel   Eco
# 4  149969    Male  Loyal Customer   30              NaN   Eco
#
#    Flight_Distance  DepartureDelayin_Mins  ArrivalDelayin_Mins
# 0              265                      0                  0.0
# 1             2138                      0                  0.0
# 2              623                      0                  0.0
# 3              354                      0                  0.0
# 4             1894                      0                  0.0

# %%
df1.shape, df2.shape
# Out:
# ((90917, 16), (90917, 9))

# %%
# Concatenate the DataFrames vertically (row-wise)
df = pd.merge(df1, df2, left_on='Id', right_on='ID')

print(df.head(3))
# Out:
#        Id             Satisfaction Seat_comfort  \
# 0  198671  neutral or dissatisfied         poor
# 1  193378                satisfied    excellent
# 2  174522                satisfied         good
#
#   Departure.Arrival.time_convenient  Food_drink Gate_location  \
# 0                        acceptable  acceptable    manageable
# 1                  need improvement   excellent    Convinient
# 2                              good        good    manageable
#
#   Inflightwifi_service Inflight_entertainment Online_support  \
# 0                 poor       need improvement           poor
# 1           acceptable              excellent     acceptable
# 2           acceptable              excellent      excellent
#
#   Ease_of_Onlinebooking  ... Online_boarding      ID  Gender  \
# 0                  poor  ...            poor  198671    Male
# 1            acceptable  ...      acceptable  193378  Female
# 2      need improvement  ...       excellent  174522  Female
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90917 entries, 0 to 90916
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Id                                 90917 non-null  int64
#  1   Satisfaction                       90917 non-null  object
#  2   Seat_comfort                       90917 non-null  object
#  3   Departure.Arrival.time_convenient  82673 non-null  object
#  4   Food_drink                         82736 non-null  object
#  5   Gate_location                      90917 non-null  object
#  6   Inflightwifi_service               90917 non-null  object
#  7   Inflight_entertainment             90917 non-null  object
#  8   Online_support                     90917 non-null  object
#  9   Ease_of_Onlinebooking              90917 non-null  object
#  10  Onboard_service                    83738 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Satisfaction', 'Seat_comfort',
#        'Departure.Arrival.time_convenient', 'Food_drink', 'Gate_location',
#        'Inflightwifi_service', 'Inflight_entertainment', 'Online_support',
#        'Ease_of_Onlinebooking', 'Onboard_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
#        'ID', 'Gender', 'CustomerType', 'Age', 'TypeTravel', 'Class',
#        'Flight_Distance', 'DepartureDelayin_Mins', 'ArrivalDelayin_Mins'],
#       dtype='object')

# %%
df1=df

# %%
df.isna().sum().sum()
# Out:
# 42075

# %%
df.isna().sum()
# Out:
# Id                                      0
# Satisfaction                            0
# Seat_comfort                            0
# Departure.Arrival.time_convenient       0
# Food_drink                              0
# Gate_location                           0
# Inflightwifi_service                    0
# Inflight_entertainment                  0
# Online_support                          0
# Ease_of_Onlinebooking                   0
# Onboard_service                         0
# Leg_room_service                        0
# Baggage_handling                        0
# Checkin_service                         0
# Cleanliness                             0
# Online_boarding                         0
# ID                                      0
# Gender                                  0
# CustomerType                         9099
# Age                                     0
# TypeTravel                              0
# Class                                   0
# ...

# %%
df = df.fillna('Unknown')
df.isna().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#        Id             Satisfaction Seat_comfort  \
# 0  198671  neutral or dissatisfied         poor
# 1  193378                satisfied    excellent
# 2  174522                satisfied         good
# 3  191830                satisfied         good
# 4  221497                satisfied         good
#
#   Departure.Arrival.time_convenient  Food_drink Gate_location  \
# 0                        acceptable  acceptable    manageable
# 1                  need improvement   excellent    Convinient
# 2                              good        good    manageable
# 3                              good        good    manageable
# 4                              good     Unknown    Convinient
#
#   Inflightwifi_service Inflight_entertainment Online_support  \
# 0                 poor       need improvement           poor
# 1           acceptable              excellent     acceptable
# 2           acceptable              excellent      excellent
# ...

# %%
mapping = {
    'extremely poor': 1,
    'poor': 2,
    'need improvement': 3,
    'acceptable': 4,
    'good': 5,
    'excellent': 6,
    'Unknown': 7
}
df = df.replace(mapping)
df.head()
# Out:
#        Id             Satisfaction  Seat_comfort  \
# 0  198671  neutral or dissatisfied             2
# 1  193378                satisfied             6
# 2  174522                satisfied             5
# 3  191830                satisfied             5
# 4  221497                satisfied             5
#
#    Departure.Arrival.time_convenient  Food_drink  Gate_location  \
# 0                                  4           4              4
# 1                                  3           6              5
# 2                                  5           5              4
# 3                                  5           5              4
# 4                                  5           7              5
#
#    Inflightwifi_service  Inflight_entertainment  Online_support  \
# 0                     2                       3               2
# 1                     4                       6               4
# 2                     4                       6               6
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Satisfaction', 'Seat_comfort',
#        'Departure.Arrival.time_convenient', 'Food_drink', 'Gate_location',
#        'Inflightwifi_service', 'Inflight_entertainment', 'Online_support',
#        'Ease_of_Onlinebooking', 'Onboard_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
#        'ID', 'Gender', 'CustomerType', 'Age', 'TypeTravel', 'Class',
#        'Flight_Distance', 'DepartureDelayin_Mins', 'ArrivalDelayin_Mins'],
#       dtype='object')

# %%
df.iloc[:, :8]
# Out:
#            Id             Satisfaction  Seat_comfort  \
# 0      198671  neutral or dissatisfied             2
# 1      193378                satisfied             6
# 2      174522                satisfied             5
# 3      191830                satisfied             5
# 4      221497                satisfied             5
# ...       ...                      ...           ...
# 90912  152951                satisfied             1
# 90913  220134                satisfied             2
# 90914  174403                satisfied             5
# 90915  224128                satisfied             5
# 90916  186039  neutral or dissatisfied             4
#
#        Departure.Arrival.time_convenient  Food_drink  Gate_location  \
# 0                                      4           4              4
# 1                                      3           6              5
# 2                                      5           5              4
# ...

# %%
df.iloc[:, 8:16]
# Out:
#        Online_support  Ease_of_Onlinebooking  Onboard_service  \
# 0                   2                      2                4
# 1                   4                      4                5
# 2                   6                      3                3
# 3                   2                      2                2
# 4                   5                      5                5
# ...               ...                    ...              ...
# 90912               5                      5                5
# 90913               6                      5                5
# 90914               6                      2                2
# 90915               5                      5                5
# 90916               5                      5                2
#
#        Leg_room_service  Baggage_handling  Checkin_service  Cleanliness  \
# 0                     4                 2                3            3
# 1                     4                 6                4            6
# ...

# %%
df.iloc[:, 16:25]
# Out:
#            ID  Gender       CustomerType  Age       TypeTravel     Class  \
# 0      198671    Male     Loyal Customer   30  Business travel  Business
# 1      193378  Female  disloyal Customer   20                7  Business
# 2      174522  Female                  7   55  Personal Travel  Eco Plus
# 3      191830    Male  disloyal Customer   24  Business travel       Eco
# 4      221497    Male     Loyal Customer   32  Business travel  Business
# ...       ...     ...                ...  ...              ...       ...
# 90912  152951  Female                  7   46  Personal Travel       Eco
# 90913  220134  Female     Loyal Customer   45                7  Business
# 90914  174403  Female     Loyal Customer   67                7       Eco
# 90915  224128  Female     Loyal Customer   37  Business travel       Eco
# 90916  186039    Male  disloyal Customer   43  Business travel  Business
#
#        Flight_Distance  DepartureDelayin_Mins  ArrivalDelayin_Mins
# ...

# %%
mapping = {
    'very inconvinient': 1,
    'Inconvinient': 2,
    'need improvement': 3,
    'manageable': 4,
    'Convinient': 5,
    'very convinient': 6,
    'manageable': 4
}

df = df.replace(mapping)

# %%
# mapping = {'Loyal Customer': 1, 'disloyal Customer': 2}
# df['CustomerType'] = df['CustomerType'].replace(mapping)
# df['CustomerType'].value_counts()
# df['CustomerType'] = df1['CustomerType']
df = pd.get_dummies(df, columns=['CustomerType'], prefix='CustomerType')
df.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'ID', 'Gender',
#        'Age', 'TypeTravel', 'Class', 'Flight_Distance',
#        'DepartureDelayin_Mins', 'ArrivalDelayin_Mins',
#        'CustomerType_Loyal Customer', 'CustomerType_disloyal Customer'],
#       dtype='object')

# %%
# mapping = {'Male': 1, 'Female': 2}
# df['Gender'] = df['Gender'].replace(mapping)
# df['Gender'].value_counts()
df['Gender'] = df1['Gender']
df = pd.get_dummies(df, columns=['Gender'], prefix='Gender')
df.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'ID', 'Age',
#        'TypeTravel', 'Class', 'Flight_Distance', 'DepartureDelayin_Mins',
#        'ArrivalDelayin_Mins', 'CustomerType_Loyal Customer',
#        'CustomerType_disloyal Customer', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
# mapping = {'Business travel': 1, 'Personal Travel': 2}
# df['TypeTravel'] = df['TypeTravel'].replace(mapping)
# df['TypeTravel'].value_counts()
df['TypeTravel'] = df1['TypeTravel']
df = pd.get_dummies(df, columns=['TypeTravel'], prefix='TypeTravel')
df.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'ID', 'Age',
#        'Class', 'Flight_Distance', 'DepartureDelayin_Mins',
#        'ArrivalDelayin_Mins', 'CustomerType_Loyal Customer',
#        'CustomerType_disloyal Customer', 'Gender_Female', 'Gender_Male',
#        'TypeTravel_Business travel', 'TypeTravel_Personal Travel'],
#       dtype='object')

# %%
# mapping = {'Business': 1, 'Eco': 2, 'Eco Plus': 3}
# df['Class'] = df['Class'].replace(mapping)
# df['Class'].value_counts()
df['Class'] = df1['Class']
df = pd.get_dummies(df, columns=['Class'], prefix='Class')
df.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'ID', 'Age',
#        'Flight_Distance', 'DepartureDelayin_Mins', 'ArrivalDelayin_Mins',
#        'CustomerType_Loyal Customer', 'CustomerType_disloyal Customer',
#        'Gender_Female', 'Gender_Male', 'TypeTravel_Business travel',
#        'TypeTravel_Personal Travel', 'Class_Business', 'Class_Eco',
#        'Class_Eco Plus'],
#       dtype='object')

# %%
df2=df
df['Satisfaction'].value_counts()
# Out:
# Satisfaction
# satisfied                  49761
# neutral or dissatisfied    41156
# Name: count, dtype: int64

# %%
mapping = {'satisfied': 1, 'neutral or dissatisfied': 0}
df['Satisfaction'] = df['Satisfaction'].replace(mapping)
df['Satisfaction'].value_counts()
# Out:
# Satisfaction
# 1    49761
# 0    41156
# Name: count, dtype: int64

# %%
df.drop('Id', axis=1, inplace=True)
df.drop('ID', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90917 entries, 0 to 90916
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Satisfaction                       90917 non-null  int64
#  1   Seat_comfort                       90917 non-null  int64
#  2   Departure.Arrival.time_convenient  90917 non-null  int64
#  3   Food_drink                         90917 non-null  int64
#  4   Gate_location                      90917 non-null  int64
#  5   Inflightwifi_service               90917 non-null  int64
#  6   Inflight_entertainment             90917 non-null  int64
#  7   Online_support                     90917 non-null  int64
#  8   Ease_of_Onlinebooking              90917 non-null  int64
#  9   Onboard_service                    90917 non-null  int64
#  10  Leg_room_service                   90917 non-null  int64
# ...

# %%
df3=df

# %%
X = df.iloc[:,1:].values
y = df.iloc[:,0].values
X.shape, y.shape
# Out:
# ((90917, 27), (90917,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 1)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((72733, 27), (18184, 27), (72733,), (18184,))

# %%
# Scaling
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential()

classifier.add(Dense(activation = 'relu', input_dim = 27, units=16, kernel_initializer='uniform'))
# Out:
# /home/akshirsagar/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.add(Dense(16, activation='sigmoid', kernel_initializer='uniform'))

# %%
classifier.add(Dense(1, activation = 'sigmoid', kernel_initializer='uniform'))

# %%
classifier.compile(optimizer='SGD', loss='mse', metrics=['accuracy'])
classifier.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 737 (2.88 KB)
#  Trainable params: 737 (2.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
classifier.fit(X_train, y_train,           
          validation_data=(X_test,y_test),
          epochs=100,
          batch_size=32)
# Out:
# Epoch 1/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 912us/step - accuracy: 0.5352 - loss: 0.2485 - val_accuracy: 0.5452 - val_loss: 0.2479
# Epoch 2/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 841us/step - accuracy: 0.5514 - loss: 0.2474 - val_accuracy: 0.5452 - val_loss: 0.2480
# Epoch 3/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 845us/step - accuracy: 0.5482 - loss: 0.2477 - val_accuracy: 0.5452 - val_loss: 0.2479
# Epoch 4/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 847us/step - accuracy: 0.5496 - loss: 0.2475 - val_accuracy: 0.5452 - val_loss: 0.2479
# Epoch 5/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 832us/step - accuracy: 0.5484 - loss: 0.2476 - val_accuracy: 0.5452 - val_loss: 0.2478
# Epoch 6/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 848us/step - accuracy: 0.5496 - loss: 0.2474 - val_accuracy: 0.5452 - val_loss: 0.2477
# Epoch 7/100
# 2273/2273 ━━━━━━━━━━━━━━━━━━━━ 2s 876us/step - accuracy: 0.5477 - loss: 0.2474 - val_accuracy: 0.5452 - val_loss: 0.2474
# Epoch 8/100
# ...

# %%
from sklearn.metrics import confusion_matrix

y_pred = classifier.predict(X_test)

y_pred = (y_pred > 0.5)

cm1 = confusion_matrix(y_test, y_pred)
print(cm1)
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# [[7580  690]
#  [ 742 9172]]

# %%
accuracy_model1 = ((cm1[0][0]+cm1[1][1])*100)/(cm1[0][0]+cm1[1][1]+cm1[0][1]+cm1[1][0])
print (accuracy_model1, '% of testing data was classified correctly')
# Out:
# 92.1249450065992 % of testing data was classified correctly
